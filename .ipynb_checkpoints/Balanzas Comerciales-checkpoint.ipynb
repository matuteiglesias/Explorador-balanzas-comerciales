# %% [markdown]
# ### Cargar modulos

# %%
import numpy as np
import pandas as pd

import sys    
reload(sys)  
sys.setdefaultencoding('utf8')

import seaborn as sns

# %% [markdown]
# ## Cargar data

# %%
data = pd.read_csv('./../Country_data/Boschma2018FilteredDataset')

## SITC Sections
SITC4_full = pd.read_csv('./SITC4_full.csv')

# %% [markdown]
# ### Ejemplito: Balanza argentina 2010 por grandes sectores

# %%
merged = data.merge(SITC4_full[['SITC ID 4', 'SITC label 1']].drop_duplicates(), left_on = 'pcode', right_on = 'SITC ID 4')

df = merged.loc[merged.ccode == 'arg'].loc[merged.year == 2010].groupby(['year', 'ccode', 'SITC label 1']).sum()[['export_val', 'import_val']]

df.style.bar(subset=['export_val', 'import_val'], color='#d65f5f')
# Out:
# <style  type="text/css" >
#     #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.8%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.6%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.2%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.7%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.8%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.9%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row4_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.4%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 47.4%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.8%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 29.8%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.7%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.8%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.6%, transparent 0%);
#         }    #T_6096247e_8b8c_11e8_82ea_5ce0c5892623row9_col1 {
#             width:  10em;
#              height:  80%;
#         }</style>
# <table id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >export_val</th>
#         <th class="col_heading level0 col1" >import_val</th>
#     </tr>    <tr>
#         <th class="index_name level0" >year</th>
#         <th class="index_name level1" >ccode</th>
#         <th class="index_name level2" >SITC label 1</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623level0_row0" class="row_heading level0 row0" rowspan=10>2010</th>
#         <th id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623level1_row0" class="row_heading level1 row0" rowspan=10>arg</th>
#         <th id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623level2_row0" class="row_heading level2 row0" >0 - Food and live animals</th>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row0_col0" class="data row0 col0" >1.6075e+10</td>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row0_col1" class="data row0 col1" >7.33416e+08</td>
#     </tr>    <tr>
#         <th id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623level2_row1" class="row_heading level2 row1" >1 - Beverages and tobacco</th>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row1_col0" class="data row1 col0" >1.1629e+09</td>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row1_col1" class="data row1 col1" >1.27683e+08</td>
#     </tr>    <tr>
#         <th id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623level2_row2" class="row_heading level2 row2" >2 - Crude materials, inedible, except fuels</th>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row2_col0" class="data row2 col0" >6.52832e+09</td>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row2_col1" class="data row2 col1" >1.15344e+09</td>
#     </tr>    <tr>
#         <th id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623level2_row3" class="row_heading level2 row3" >3 - Mineral fuels, lubricants and related materials</th>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row3_col0" class="data row3 col0" >2.62599e+09</td>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row3_col1" class="data row3 col1" >7.37761e+08</td>
#     </tr>    <tr>
#         <th id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623level2_row4" class="row_heading level2 row4" >4 - Animal and vegetable oils, fats and waxes</th>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row4_col0" class="data row4 col0" >1.08585e+08</td>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row4_col1" class="data row4 col1" >4.80258e+07</td>
#     </tr>    <tr>
#         <th id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623level2_row5" class="row_heading level2 row5" >5 - Chemicals and related products, n.e.s.</th>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row5_col0" class="data row5 col0" >4.00185e+09</td>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row5_col1" class="data row5 col1" >7.01716e+09</td>
#     </tr>    <tr>
#         <th id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623level2_row6" class="row_heading level2 row6" >6 - Manufactured goods classified chiefly by material</th>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row6_col0" class="data row6 col0" >4.07031e+09</td>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row6_col1" class="data row6 col1" >4.42418e+09</td>
#     </tr>    <tr>
#         <th id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623level2_row7" class="row_heading level2 row7" >7 - Machinery and transport equipment</th>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row7_col0" class="data row7 col0" >5.4861e+09</td>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row7_col1" class="data row7 col1" >1.4786e+10</td>
#     </tr>    <tr>
#         <th id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623level2_row8" class="row_heading level2 row8" >8 - Miscellaneous manufactured articles</th>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row8_col0" class="data row8 col0" >7.22948e+08</td>
#         <td id="T_6096247e_8b8c_11e8_82ea_5ce0c5892623row8_col1" class="data row8 col1" >

# %% [markdown]
# ## Exportaciones, importaciones y saldo

# %%
data['decada'] = data['year'].round(-1)
# data['import_val'] = - data['import_val']
data['saldo'] = data['export_val'] - data['import_val']
grouped = data.groupby(['decada', 'ccode', 'pcode'])[['export_val', 'import_val', 'saldo']].sum()/1000000./10.

# %%
def get_main_entries(df, column, pct = .8):
    sorted = df.sort_values(by = column, ascending = False)
    pct_cumsum = sorted[column].cumsum()/sorted[column].sum()
    sorted_sel = sorted[pct_cumsum < pct]

    return sorted_sel

pr = pd.read_csv('./products_sitc_rev2.tsv', delimiter = '\t')
pr.columns = ['id', 'SITC ID 4', 'SITC label 4']

# %% [markdown]
# ## Explorador de balanzas comerciales
# ### Ver balanza eligiendo pais, decada o productos.  (millones de USD promedio anual)

# %%
decada = 2010
pais = 'arg'
# producto = 5417 # Medicamentos
ordenar_por = 'import_val'

df = grouped.reset_index()
df_summary = get_main_entries(df.loc[(df.decada == decada) & (df.ccode == pais)], ordenar_por, .9)
df_summary = df_summary.merge(pr[['SITC ID 4', 'SITC label 4']], left_on = 'pcode', right_on = 'SITC ID 4', how = 'left')
df_summary = df_summary[['decada', 'ccode', 'pcode','SITC label 4', 'export_val', 'import_val', 'saldo']]

# Muestra top 15
df_summary.head(15).style.bar(subset=['export_val', 'import_val', 'saldo'], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 25.7%, #d65f5f 25.7%, #d65f5f 51.3%, transparent 51.3%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 48.5%, transparent 48.5%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 82.1%, transparent 82.1%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent -0.0%, #d65f5f -0.0%, #d65f5f 51.3%, transparent 51.3%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 34.5%, transparent 34.5%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 70.0%, transparent 70.0%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 1.5%, #d65f5f 1.5%, #d65f5f 51.3%, transparent 51.3%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 26.3%, transparent 26.3%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 35.4%, transparent 35.4%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 34.0%, #d65f5f 34.0%, #d65f5f 51.3%, transparent 51.3%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 0.2%, transparent 0.2%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 31.4%, transparent 31.4%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 15.2%, #d65f5f 15.2%, #d65f5f 51.3%, transparent 51.3%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 84.9%, transparent 84.9%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row5_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 23.9%, transparent 23.9%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row5_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.3%, #5fba7d 51.3%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 20.1%, transparent 20.1%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row6_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 22.4%, transparent 22.4%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row6_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 43.5%, #d65f5f 43.5%, #d65f5f 51.3%, transparent 51.3%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 19.8%, transparent 19.8%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row7_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 20.6%, transparent 20.6%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row7_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.3%, #d65f5f 45.3%, #d65f5f 51.3%, transparent 51.3%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row8_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 4.9%, transparent 4.9%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row8_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 19.1%, transparent 19.1%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row8_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.6%, #d65f5f 33.6%, #d65f5f 51.3%, transparent 51.3%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row9_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 9.2%, transparent 9.2%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row9_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 18.1%, transparent 18.1%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row9_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 38.7%, #d65f5f 38.7%, #d65f5f 51.3%, transparent 51.3%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row10_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 0.1%, transparent 0.1%);
#         }    #T_a0a3460e_8b8d_11e8_82ea_5ce0c5892623row10_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 16.2%, transparent 16.2%);
#         }    #T_a0a3460e_8b8d
